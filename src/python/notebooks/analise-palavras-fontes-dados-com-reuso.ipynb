# %% [markdown]
# # Análise palavras fontes de dados

# %%
from explore.informacoes_fontes_dados import obter_informacoes_palavras
from explore.estatistica_palavras_nerds_viajantes import AnaliseEstatisticaPalavras
from explore.grafico_palavras_nerds_viajantes import AnaliseGraficaPalavras
from explore.nuvem_palavras_nerds_viajantes import AnaliseNuvemPalavras

from util import constants

# %% [markdown]
# ## Análises gráficas de palavras de fontes de dados

# %% [markdown]
# ## Análise palavras - Nerds Viajantes

# %%
informacoes_fonte_de_dados = obter_informacoes_palavras(constants.NERDS_VIAJANTES)

# %%
informacoes_fonte_de_dados.head(5)
# Out:
#                                            documento  tamanho  \
# 0  [prim, dia, santiag, tent, visit, mus, art, pr...      197
# 1  [sext, feir, santiag, ped, restaurant, bacan, ...      190
# 2  [palaci, moned, soment, moned, sed, govern, ch...      147
# 3  [inaugur, hoj, seç, revel, fot, tod, seman, po...      119
# 4  [monument, valley, reg, est, unid, fic, dentr,...      113
#
#                                  documento_nao_verbo  tamanho_sem_verbo  \
# 0  [dia, santiag, mus, art, pré, colombi, vár, me...                117
# 1  [santiag, restaurant, bacan, dentr, opç, diver...                118
# 2  [palaci, moned, soment, moned, chilen, santiag...                 75
# 3  [hoj, seç, fot, tod, seman, fot, fot, câm, alg...                 64
# 4  [monument, valley, unid, dentr, indígen, trib,...                 59
#
#    percentual_nao_verbo                             documento_nao_verbo_sw  \
# 0             59.390863  [santiag, mus, art, pré, colombi, vár, mes, pe...
# 1             62.105263  [santiag, bacan, dentr, opç, divers, blog, aqu...
# 2             51.020408  [palaci, moned, soment, moned, chilen, santiag...
# 3             53.781513  [hoj, seç, seman, câm, ent, últ, chil, argenti...
# 4             52.212389  [monument, valley, unid, dentr, indígen, trib,...
#
#    tamanho_sem_verbo_sw  percentual_nao_verbo_sw
# 0                   109                55.329949
# 1                   105                55.263158
# 2                    73                49.659864
# 3                    54                45.378151
# 4                    51                45.132743

# %% [markdown]
# ## Análise fonte de dados selecionada

# %%
analise_grafica = AnaliseGraficaPalavras(informacoes_fonte_de_dados)

# %% [markdown]
# ### Distribuição de percentuais de tokens não verbo no documento

# %%
analise_grafica.analisar_distribuicao_percentual('percentual_nao_verbo')

# %% [markdown]
# ### Distribuição de percentuais de tokens não verbo nem stopwords no documento

# %%
analise_grafica.analisar_distribuicao_percentual('percentual_nao_verbo_sw')

# %% [markdown]
# ### Distribuição de tamanho de documento

# %%
analise_grafica.analisar_distribuicao_tamanhos_documentos()

# %%
analise_grafica.analisar_distribuicao_tamanhos_documentos(bidimensional=True)

# %%
analise_grafica.analisar_distribuicao_tamanhos_documentos(bidimensional=True, x_max=300)

# %%
analise_grafica.analisar_distribuicao_tamanhos(indicador_tamanho='tamanho_sem_verbo')

# %%
analise_grafica.analisar_distribuicao_tamanhos(indicador_tamanho='tamanho_sem_verbo', x_max=600)

# %%
analise_grafica.analisar_distribuicao_tamanhos()

# %%
analise_grafica.analisar_distribuicao_tamanhos(x_max=750)

# %% [markdown]
# ## Análise estatística da fonte selecionada

# %%
analise_estatistica = AnaliseEstatisticaPalavras(informacoes_fonte_de_dados)

# %% [markdown]
# ### Contagem geral de tokens

# %%
analise_estatistica.exibir_total_tokens('documento')
# Out:
# O total de tokens de todos os documentos para a coluna "documento" eh 113364

# %%
analise_estatistica.exibir_total_tokens('documento_nao_verbo')
# Out:
# O total de tokens de todos os documentos para a coluna "documento_nao_verbo" eh 60548

# %% [markdown]
# ### Exibição de tokens mais frequentes

# %% [markdown]
# #### 10 tokens mais frequentes

# %%
print('10 Tokens mais comuns entre todos os tokens:')
analise_estatistica.exibir_tokens_mais_comuns('documento')

print('10 Tokens mais comuns eliminando os verbos:')
analise_estatistica.exibir_tokens_mais_comuns('documento_nao_verbo')
# Out:
# 10 Tokens mais comuns entre todos os tokens:
# [('fot', 1549), ('fic', 807), ('algum', 669), ('par', 660), ('caminh', 639), ('cheg', 611), ('pod', 599), ('visit', 581), ('fotograf', 566), ('passei', 560)]
# 10 Tokens mais comuns eliminando os verbos:
# [('fot', 1549), ('algum', 669), ('passei', 560), ('parqu', 557), ('outr', 551), ('cidad', 534), ('muit', 501), ('temp', 484), ('tod', 441), ('pouc', 422)]

# %% [markdown]
# #### 20 tokens mais frequentes

# %%
print('20 Tokens mais comuns entre todos os tokens:')
analise_estatistica.exibir_tokens_mais_comuns('documento', n=20)

print('20 Tokens mais comuns eliminando os verbos:')
analise_estatistica.exibir_tokens_mais_comuns('documento_nao_verbo', n=20)
# Out:
# 20 Tokens mais comuns entre todos os tokens:
# [('fot', 1549), ('fic', 807), ('algum', 669), ('par', 660), ('caminh', 639), ('cheg', 611), ('pod', 599), ('visit', 581), ('fotograf', 566), ('passei', 560), ('parqu', 557), ('trilh', 554), ('faz', 552), ('outr', 551), ('cidad', 534), ('pass', 526), ('muit', 501), ('hor', 489), ('temp', 484), ('local', 463)]
# 20 Tokens mais comuns eliminando os verbos:
# [('fot', 1549), ('algum', 669), ('passei', 560), ('parqu', 557), ('outr', 551), ('cidad', 534), ('muit', 501), ('temp', 484), ('tod', 441), ('pouc', 422), ('lag', 364), ('jalap', 361), ('águ', 353), ('aind', 350), ('bonit', 348), ('vist', 338), ('bel', 322), ('pra', 297), ('lug', 297), ('fiz', 296)]

# %% [markdown]
# ### Descrição estatística dos tamanhos dos documentos

# %%
analise_estatistica.analisar_tamanhos_documentos()
# Out:
#            tamanho  tamanho_sem_verbo
# count   378.000000         378.000000
# mean    299.904762         160.179894
# std     232.226409         128.472579
# min      10.000000           5.000000
# 5%      108.700000          55.000000
# 10%     130.700000          66.700000
# 25%     162.250000          83.000000
# 50%     214.000000         115.000000
# 75%     359.500000         197.750000
# 90%     580.100000         303.500000
# 95%     740.000000         381.200000
# max    1878.000000        1098.000000

# %% [markdown]
# ## Nuvem de palavras

# %%
analise_nuvem_palavras = AnaliseNuvemPalavras(informacoes_fonte_de_dados)

# %% [markdown]
# ## Nuvem de palavras da fonte selecionada

# %%
analise_nuvem_palavras.gerar_nuvem_palavras('documento_nao_verbo')

# %%
analise_nuvem_palavras.gerar_nuvem_palavras('documento')

# %% [markdown]
# ## Análise de 100 palavras que mais aparecem

# %%
documentos = informacoes_fonte_de_dados['documento'].values

# %%
documentos[:5]
# Out:
# array([list(['prim', 'santiag', 'tent', 'visit', 'mus', 'art', 'pré', 'colombi', 'cheg', 'local', 'depar', 'vár', 'mes', 'pesso', 'jog', 'cart', 'tarot', 'com', 'prim', 'santiag', 'ach', 'situ', 'inusit', 'depois', 'vim', 'sup', 'comum', 'rua', 'cidad', 'procur', 'bilhet', 'mus', 'depar', 'plac', 'avis', 'mus', 'fech', 'reform', 'muit', 'trist', 'consult', 'sit', 'mus', 'perceb', 'fech', 'dezembr', '2011', 'final', '2013', 'previs', 'dat', 'cert', 'reabr', 'ness', 'períod', 'espaç', 'mus', 'ampli', '1600', 'est', 'mudanç', 'permitir', 'aument', 'espaç', 'expos', 'mostr', 'públic', 'quas', 'dobr', 'coleç', 'patrimon', 'mus', 'coleç', 'mus', 'agrup', 'áre', 'cult', 'mesoamér', 'méxic', 'guatemal', 'hond', 'salv', 'part', 'nicarágu', 'interméd', 'colômb', 'equ', 'carib', 'mar', 'carib', 'antill', 'ama', 'selv', 'amazôn', 'and', 'centr', 'peru', 'bolív', 'and', 'sul', 'chil', 'argentin', 'vej', 'posicion', 'mus', 'através', 'map', 'seguint', 'par', 'quis', 'program', 'visit', '2013', 'segu', 'algum', 'inform', 'essenc', 'hor', 'terç', 'feir', 'doming', 'segund', 'feir', 'fech', 'entr', 'públic', 'geral', '000', 'estud', '000', 'crianç', 'ano', 'entr', 'liber', 'ob', 'val', 'consult', 'através', 'sit', 'mus', 'jan', '2012', 'pod', 'sofr', 'alter', 'mus', 'reabr', 'dur', 'ano', 'mus', 'permanec', 'fech', 'dur', 'seguint', 'dia', 'jan', 'seman', 'sant', 'sext', 'feir', 'sáb', 'doming', 'mai', 'setembr', 'feri', 'fic', 'abert', 'mei', 'endereç', 'band', '361', 'santiag', 'chil', 'metrô', 'estaçã', 'plaz', 'arm', 'linh', 'dist', 'aproxim', '240', 'metr', 'sit', 'mus', 'http', 'www', 'precolombin', 'qu', 'reabr', 'visit', 'mus', 'cont', 'experi']),
#        list(['sext', 'feir', 'santiag', 'ped', 'restaurant', 'bacan', 'jant', 'dentr', 'opç', 'suger', 'divers', 'blog', 'acompanh', 'escolh', 'experiment', 'restaurant', 'aquí', 'est', 'coc', 'elogi', 'blog', 'destemper', 'com', 'diss', 'concorr', 'lig', 'restaurant', 'reserv', 'mes', 'jant', 'cheg', 'restaurant', 'acomod', 'mes', 'varand', 'local', 'agrad', 'prim', 'impress', 'restaurant', 'ótim', 'garçom', 'educ', 'agrad', 'hor', 'escolh', 'vinh', 'dúv', 'cruel', 'muit', 'opç', 'bacan', 'fom', 'auxili', 'sommeli', 'restaurant', 'recomend', 'pinot', 'noir', 'undurrag', '2010', 'começ', 'divid', 'entr', 'salm', 'marin', 'lâmin', 'salm', 'marin', 'sal', 'gross', 'cobert', 'endr', 'noss', 'escolh', 'prat', 'princip', 'congr', 'salte', 'pedaç', 'congr', 'frit', 'cebol', 'rox', 'tomat', 'piment', 'amarel', 'coentr', 'acompanh', 'batat', 'frit', 'cas', 'noss', 'cláss', 'congr', 'mai', 'mai', 'filé', 'congr', 'molh', 'fresc', 'presunt', 'milh', 'verd', 'champinhon', 'gamb', 'acompanh', 'batat', 'vap', 'delici', 'sobrem', 'tulip', 'berri', 'tulip', 'kiwich', 'mist', 'frut', 'vermelh', 'berri', 'marin', 'carmenérè', 'acompanh', 'sorvet', 'artesan', 'baunilh', 'irresistibl', 'chocolat', 'uma', 'suav', 'text', 'chocolat', 'pret', 'branc', 'cald', 'laranj', 'limã', 'val', 'total', 'cont', '400', 'val', 'cad', 'centav', 'final', 'ped', 'conhec', 'ambi', 'garçom', 'sup', 'agrad', 'prontific', 'apresent', 'cad', 'cant', 'local', 'com', 'chei', 'fic', 'mei', 'graç', 'tir', 'fot', 'ambi', 'intern', 'porém', 'sit', 'restaurant', 'vár', 'fot', 'descr', 'tod', 'ambi', 'restaurant', 'restaurant', 'client', 'nerd', 'agradec', 'endereç', 'concepción', '236', 'providenc', 'santiag', 'chil', 'telefon', '410', '6200', 'sit', 'http', 'www', 'aquiestacoc']),
#        list(['palaci', 'moned', 'soment', 'moned', 'sed', 'govern', 'chilen', 'local', 'centr', 'santiag', 'paláci', 'rode', 'dua', 'praç', 'plaz', 'constituición', 'plaz', 'ciudadaní', 'paláci', 'constru', 'abrig', 'cas', 'moed', 'chil', 'aind', 'colôn', 'espanhol', '1845', 'palaci', 'moned', 'transform', 'sed', 'govern', 'chilen', 'resid', 'ofic', 'presid', 'reg', 'paláci', 'agrad', 'princip', 'plaz', 'constituición', 'muit', 'flor', 'rode', 'grand', 'árvor', 'faz', 'sombr', 'banc', 'ond', 'muit', 'chilen', 'descans', 'hor', 'almoç', 'sup', 'agrad', 'val', 'pen', 'sent', 'pouc', 'descans', 'observ', 'moviment', 'local', 'uma', 'atr', 'interess', 'troc', 'guard', 'infeliz', 'program', 'assist', 'troc', 'recomend', 'cheg', 'ced', 'par', 'consult', 'calend', 'troc', 'guard', 'visit', 'sit', 'http', 'www', 'gobiernodechil', 'moned', 'cambi', 'guard', 'possível', 'faz', 'visit', 'gui', 'dentr', 'paláci', 'com', 'pouc', 'temp', 'cidad', 'fiz', 'mas', 'cert', 'nov', 'pass', 'cidad', 'program', 'tour', 'paláci', 'par', 'mai', 'detalh', 'agend', 'visit', 'gui', 'consult', 'sit', 'http', 'www', 'gobiernodechil', 'moned', 'ven', 'conoc', 'moned', 'com', 'cheg', 'endereç', 'localiz', 'rua', 'moned', 'teatin', 'morandé', 'alamed', 'del', 'libert', 'bernard', 'higgim', 'metrô', 'estaçã', 'moned', 'linh', 'dist', 'aproxim', '150', 'metr']),
#        list(['inaugur', 'hoj', 'seç', 'revel', 'fot', 'tod', 'seman', 'post', 'fot', 'viag', 'revel', 'mai', 'detalh', 'fot', 'tir', 'local', 'hor', 'configur', 'câm', 'algum', 'dic', 'fotograf', 'começ', 'ent', 'fot', 'últ', 'viag', 'chil', 'argentin', 'est', 'passe', 'frutill', 'baj', 'beir', 'lag', 'llanquihu', 'observ', 'vist', 'vulc', 'osorn', 'demal', 'vulc', 'caminh', 'pass', 'deck', 'ond', 'pod', 'ter', 'bel', 'vist', 'vulc', 'teatr', 'cidad', 'sair', 'deck', 'resolv', 'fotograf', 'própri', 'deck', 'ach', 'bonit', 'luminár', 'local', 'pis', 'mad', 'padr', 'geométr', 'cham', 'atenç', 'ser', 'imposs', 'tir', 'fot', 'ninguém', 'ser', 'madrug', 'porém', 'dav', 'pra', 'escolh', 'moment', 'pesso', 'afast', 'cham', 'muit', 'atenç', 'até', 'cachorr', 'aparec', 'hor', 'ediç', 'ach', 'fot', 'fic', 'interess', 'pret', 'branc', 'ei', 'result', 'esper', 'gost', 'seman', 'vem', 'configur', 'dat', '2012', 'hor', 'sinal', 'hor', 'recomend', 'fotograf', 'dist', 'focal', '28mm', 'expos', '1250', 'abert', 'iso', '100']),
#        list(['monument', 'valley', 'reg', 'est', 'unid', 'fic', 'dentr', 'reserv', 'indígen', 'trib', 'navaj', 'fam', 'roch', 'avermelh', 'send', 'cen', 'divers', 'film', 'faroest', 'outr', 'gêner', 'desenh', 'anim', 'film', 'fam', 'grav', 'monument', 'valley', 'forrest', 'gump', 'lev', 'instal', 'plac', 'reserv', 'homen', 'pont', 'final', 'corr', 'fiz', 'revel', 'fot', 'espec', 'plac', 'forrest', 'gump', 'últ', 'visit', 'monument', 'valley', 'opt', 'fic', 'hosped', 'fic', 'local', 'dentr', 'reserv', 'apreci', 'tranquil', 'fim', 'tard', 'amanhec', 'seguint', 'após', 'percorr', 'milh', 'estr', 'loop', 'atravess', 'parqu', 'fic', 'aguard', 'fim', 'tard', 'fom', 'surpreend', 'vár', 'nuv', 'encobr', 'sol', 'temp', 'der', 'oportun', 'faz', 'pret', 'branc', 'bast', 'dramá', 'ver', 'nuv', 'sobr', 'mitten', 'pens', 'compos', 'tir', 'fot', 'varand', 'quart', 'vej', 'result', 'configur', 'dat', '2011', 'hor', 'dist', 'focal', 'expos', 'abert', 'iso', '100'])],
#       dtype=object)
